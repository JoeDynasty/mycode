# %%
# First Version with if statment 
#total NPS score = [first costumer, second, third, fourth, fifth]

#NPS = [a, b, c, d, e]
"""
a = input("First costumer NPS score between 1 to 5")
b = input("Second costumer NPS score between 1 to 5")
c = input("Third costumer NPS score between 1 to 5")
d = input("Fourth costumer NPS score between 1 to 5")
e = input("Fifth costumer NPS score between 1 to 5")
"""
#NPS scores is reflected between -100 to 100, meaning that:
#-100 is value 1
#-50 is value 2
#0 is value 3
#50 is value 4
#100 is value 5

# You cannot get a score of 0

value = float(input("Enter your costumer score (between 1-5): "))

if value == 5:
    print("Your NPS is 100, good job!")
elif value == 4:
    print("Your NPS is 50")
elif value == 3:
    print("Your NPS is 0")
elif value == 2:
    print("Your NPS is -50")
elif value == 1:
    print("Your NPS is -100")
else:
    print("Please type in your costumer score again")

#def calculate_NPS()

#total NPS = (a + b + c + d + e)/n; n = total number of costumer

# %%
#Second Version with loops
'''
NPS = 0

s = float(input("Enter your costumer NPS score: "))
i = 1
while s != 0 or i == 30:
    n = int(s)
    NPS = 50*s - 150 #slope of the expression is NPS = 50s - 150 (y = mx + b)
    avg_NPS = NPS*s/i
    s = float(input("Enter another costumer NPS score or type 0 for done: ")
    i = i + 1
print("Your overall score " + str(avg_NPS))
'''

# %%
#Third Version


'''
Goal: input any amount of costumer rating, and return the total average NPS score between -100 to 100. 


NPS: Net promotor score

rating between 1-5 

assign each rating to it's responding NPS value:

#-100 is value 1
#-50 is value 2
#0 is value 3
#50 is value 4
#100 is value 5

lets treat the rating as str, and not an int

Goal: get input as loops of different list of rating, and return 

'''
value = []
i = 0

while value != "0" or i == 0:
    value = str(input("Enter your costumer score (between 1-5): "))
    if value == "5":
        score = 100
        value = str(input("Enter another costumer NPS score or type 'done': "))
    elif value == "4":
        score = 50
    elif value == "3":
        score = 0
    elif value == "2":
        score = (-50)
    elif value == "1":
        score = (-100)
    else:
        print("Number has to be between 1-5, please try again!")

    
    
def cal_average(total_values):
    average = total_values / i
# Out:
# Enter your costumer score (between 1-5):  5
# Enter another costumer NPS score or type 'done':  5
# Enter your costumer score (between 1-5):  5
# Enter another costumer NPS score or type 'done':  3
# Enter your costumer score (between 1-5):  2
# Enter your costumer score (between 1-5):  4
# Enter your costumer score (between 1-5):  5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /opt/conda/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
# ...
